# %%
from game import game

# %%
game()
# Out:
# Executing heuristic_fd...
# Agent position: (2, 33)
# Target position: (12, 44)
# Monster position: [(1, 50), (2, 50), (18, 33), (18, 49), (18, 50)]
#
# Executing heuristic_gg...
# Agent position: (2, 33)
# Target position: (12, 44)
# Monster position: [(1, 50), (2, 50), (18, 33), (18, 49), (18, 50)]
